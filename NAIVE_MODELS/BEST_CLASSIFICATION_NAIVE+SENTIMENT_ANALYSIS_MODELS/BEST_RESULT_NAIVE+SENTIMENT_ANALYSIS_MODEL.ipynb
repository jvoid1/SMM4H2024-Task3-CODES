# %% [markdown]
# ## **MULTINOMIAL NAIVE BAYES 2 LABELS CON PROMEDIO DE PALABRAS TEXT/LABEL TFIDFVECTORIZER**

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from google.colab import drive
import joblib

# Montar Google Drive
drive.mount('/content/drive')

# Descargar el recurso 'stopwords'
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# Mounted at /content/drive
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Inicializar el stemmer en inglés
stemmer = SnowballStemmer('english')

# Función para realizar stemming en el texto
def stem_text(text):
    # Tokenizar el texto
    tokens = word_tokenize(text)
    # Realizar stemming en cada token y excluir las stopwords
    stemmed_words = [stemmer.stem(word) for word in tokens if word.lower() not in stopwords.words('english')]
    return ' '.join(stemmed_words)

# Cargar los datos
data = pd.read_csv('SMM4H_2024_Task3_Training_1800.csv', nrows=1800, usecols=[1, 2, 3], engine='python')

# Lematizar las columnas 'keyword' y 'text'
data['keyword'] = data['keyword'].apply(stem_text)
data['text'] = data['text'].apply(stem_text)

# Reemplazar los valores de la columna 'label' que no son 0 por 1
data['label'] = data['label'].apply(lambda x: 1 if x != 0 else x)

# Partición de los datos en train, validation y test
train_data, temp_data = train_test_split(data, test_size=0.2, stratify=data['label'], random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, stratify=temp_data['label'], random_state=42)

# Calcular el promedio de palabras en el texto para cada clase
data['word_count'] = data['text'].apply(lambda x: len(x.split()))
class_word_counts = data.groupby('label')['word_count'].mean()
print(class_word_counts)

# Normalizar los valores del promedio de palabras
max_word_count = class_word_counts.max()
min_word_count = class_word_counts.min()
normalized_class_word_counts = (class_word_counts - min_word_count) / (max_word_count - min_word_count)

# Añadir la característica normalizada como una columna adicional en los datos
train_data['normalized_word_count'] = train_data['label'].map(normalized_class_word_counts)
val_data['normalized_word_count'] = val_data['label'].map(normalized_class_word_counts)
test_data['normalized_word_count'] = test_data['label'].map(normalized_class_word_counts)

# Partición de los datos en train, validation y test
X_train = train_data[['text', 'normalized_word_count']]
X_val = val_data[['text', 'normalized_word_count']]
X_test = test_data[['text', 'normalized_word_count']]
y_train = train_data['label']
y_val = val_data['label']
y_test = test_data['label']

print('test_data',X_test)

# Preprocesamiento de texto y construcción del modelo
vectorizer = TfidfVectorizer()
model = MultinomialNB()

# Entrenar el modelo
X_train_text = vectorizer.fit_transform(X_train['text'])
X_train_combined = np.hstack((X_train_text.toarray(), np.array(X_train['normalized_word_count']).reshape(-1, 1)))
model.fit(X_train_combined, y_train)

# Validación del modelo
X_val_text = vectorizer.transform(X_val['text'])
X_val_combined = np.hstack((X_val_text.toarray(), np.array(X_val['normalized_word_count']).reshape(-1, 1)))
predicted_labels = model.predict(X_val_combined)

# Evaluación del modelo
print("Resultados en datos de validación:")
print(classification_report(y_val, predicted_labels))

# Prueba del modelo
X_test_text = vectorizer.transform(X_test['text'])
X_test_combined = np.hstack((X_test_text.toarray(), np.array(X_test['normalized_word_count']).reshape(-1, 1)))
predicted_labels_test = model.predict(X_test_combined)

# Evaluación del modelo en los datos de prueba
print("\nResultados en datos de prueba:")
print(classification_report(y_test, predicted_labels_test))
# Out:
# label
# 0    111.706454
# 1    150.692078
# Name: word_count, dtype: float64
# test_data                                                    text  normalized_word_count
# 1573  feel ya buddi , spent day loung around home , ...                    1.0
# 460   sure tell regard possibl swim problem futur , ...                    0.0
# 315   although subject frustrat , n't let beauti thi...                    0.0
# 1659  struggl get outsid . start thing : 'm 21 year ...                    1.0
# 1179  recent went run / walk . took like week actual...                    1.0
# ...                                                 ...                    ...
# 161   sever anxiety/depress . 'm 20 year old dude di...                    0.0
# 654   anxieti roof ! . past week two get rid one dog...                    0.0
# 957   n't realli tast music . younger probabl tast w...                    0.0
# 744                         ’ outsid though . ’ peopl .                    0.0
# 619   pretti much , 's exact get thing done make com...                    0.0
#
# [180 rows x 2 columns]
# Resultados en datos de validación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       113
#            1       1.00      1.00      1.00        67
#
#     accuracy                           1.00       180
#    macro avg       1.00      1.00      1.00       180
# weighted avg       1.00      1.00      1.00       180
#
#
# Resultados en datos de prueba:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       113
#            1       1.00      1.00      1.00        67
#
#     accuracy                           1.00       180
#    macro avg       1.00      1.00      1.00       180
# weighted avg       1.00      1.00      1.00       180

# %%
print(len(data['text']))

# Transformar los datos de texto de todos los datos utilizando el mismo vectorizador
X_all_data_text = vectorizer.transform(data['text'])

# Calcular el promedio de palabras en el texto para cada clase
data['word_count'] = data['text'].apply(lambda x: len(x.split()))
class_word_counts = data.groupby('label')['word_count'].mean()

# Normalizar los valores del promedio de palabras
max_word_count = class_word_counts.max()
min_word_count = class_word_counts.min()
normalized_class_word_counts = (class_word_counts - min_word_count) / (max_word_count - min_word_count)

# Añadir la característica normalizada como una columna adicional en los datos
data['normalized_word_count'] = data['label'].map(normalized_class_word_counts)

# Transformar los datos de texto de todos los datos utilizando el mismo vectorizador
X_all_data_text = vectorizer.transform(data['text'])

# Combinar las características de texto y la característica normalizada
X_all_data_combined = np.hstack((X_all_data_text.toarray(), np.array(data['normalized_word_count']).reshape(-1, 1)))

# Predecir las etiquetas para todos los datos
predicted_labels_all_data = model.predict(X_all_data_combined)

# Evaluación del modelo en todos los datos
print("\nResultados en todos los datos:")
print(classification_report(data['label'], predicted_labels_all_data))
# Out:
# 1800
#
# Resultados en todos los datos:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1131
#            1       1.00      1.00      1.00       669
#
#     accuracy                           1.00      1800
#    macro avg       1.00      1.00      1.00      1800
# weighted avg       1.00      1.00      1.00      1800

# %%
# Filtrar el dataframe para obtener solo los textos con etiqueta predicha como 1
print(len(predicted_labels_all_data))
new_data_class_2 = data[data['label'] == 1]  # Filtrar el dataframe original por las predicciones 0
print(new_data_class_2)
# Out:
# 1800
#                                    keyword  \
# 1131                                  walk
# 1132                         outsid , bike
# 1133                                  walk
# 1134                                   run
# 1135               run , run , hors , walk
# ...                                    ...
# 1795                   pool , beach , pool
# 1796                      outsid , outdoor
# 1797                                   jog
# 1798                    walk , swim , pool
# 1799  roller blade , outsid , roller blade
#
#                                                    text  label  word_count  \
# 1131  feel like text send back forth pretti flirtati...      1         111
# 1132  'm gon na pokemon thing get go outsid , bike ....      1          50
# 1133  someth work expos anxieti . even though 'm sta...      1         266
# 1134  absolut ! pleas encourag son . , make son exer...      1          93
# 1135  agre feel good thing . use go run track field ...      1          70
# ...                                                 ...    ...         ...
# 1795  social anxieti : essenti . look around , felt ...      1        1242
# 1796  eye contact . public . ca n't . hi , 'm 17 tho...      1         225
# 1797  look light , find . look dark , ever see.nnmi ...      1          91
# 1798  feel like sa ruin life . hi , hope okay post ....      1        1150
# 1799  got social anxieti tri roller blade . 24 year ...      1         204
#
#       normalized_word_count
# 1131                    1.0
# 1132                    1.0
# 1133                    1.0
# 1134                    1.0
# 1135                    1.0
# ...                     ...
# 1795                    1.0
# 1796                    1.0
# 1797                    1.0
# 1798                    1.0
# 1799                    1.0
#
# [669 rows x 5 columns]

# %%
# Filtrar el dataframe para obtener solo los textos con etiqueta predicha como 0
new_data = data[data['label'] == 0]  # Filtrar el dataframe original por las predicciones 0
print(new_data)
# Out:
#                  keyword                                               text  \
# 0                    run  21/m . want experi young love , ve never relat...
# 1                 outsid  issu talk girl enjoy , sinc ignor pms most .. ...
# 2     run , swim , climb  need advic free social activ . ve come shell b...
# 3                   walk  spoke today .. week ago met girl colleg biolog...
# 4                 outsid  get social anxieti ? . hello , day girlfriend ...
# ...                  ...                                                ...
# 1126           basketbal  stiff . social anxieti make stiff ’ like muscl...
# 1127                 run  struggl set boundari friend alway come back bi...
# 1128                pool  think 'm make progress , realis far still go ....
# 1129                 run  help ? : ( . ’ know make friend . ’ 21 year ol...
# 1130       outsid , walk  random peopl take insecur ? . outsid break lad...
#
#       label  word_count  normalized_word_count
# 0         0          84                    0.0
# 1         0         204                    0.0
# 2         0         212                    0.0
# 3         0         234                    0.0
# 4         0         162                    0.0
# ...     ...         ...                    ...
# 1126      0          57                    0.0
# 1127      0         404                    0.0
# 1128      0         145                    0.0
# 1129      0         137                    0.0
# 1130      0          41                    0.0
#
# [1131 rows x 5 columns]

# %%
# Guardar el modelo en un archivo
joblib.dump(model, 'naive_bayes_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')

# Copiar el archivo del modelo a Google Drive
# !cp naive_bayes_model.pkl '/content/drive/My Drive/'
# !cp vectorizer.pkl '/content/drive/My Drive/'

# %% [markdown]
# ---
#
# ## **SENTIMENT ANALYSIS**
#
# ## **MODEL: cardiffnlp/twitter-roberta-base-sentiment**

# %%
import pandas as pd
from sklearn.metrics import classification_report
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer

# Cargar el dataframe resultante del primer código
data = pd.read_csv('SMM4H_2024_Task3_Training_1800.csv', nrows=1800, usecols=[0, 1, 2, 3], engine='python')

# Preprocesamiento de los textos para el clasificador
formatted_texts = new_data_class_2['text'].apply(lambda text: f"('{text}')")

# Crear el clasificador de sentimiento
task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
sentiment_task = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

# Realizar las predicciones para los nuevos textos
predictions_5 = []
x = 0
for i, text in enumerate(formatted_texts):
    try:
        # Tokenizar el texto para obtener los token_type_ids
        inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
        # Extraer la cadena de texto del tensor de entrada
        text_input = tokenizer.decode(inputs["input_ids"][0], skip_special_tokens=True)
        # Hacer la predicción con la cadena de texto
        output_5 = sentiment_task(text_input)
        # Obtener la etiqueta de la predicción
        label = output_5[0]['label']
        # Convertir la etiqueta a su valor numérico
        if label == 'LABEL_2':
            predictions_5.append(1)
        elif label == 'LABEL_1':
            predictions_5.append(2)
        else:
            predictions_5.append(3)
    except Exception as e:
        print(f"Error al procesar texto {text}: {e}")
        # Asignar un valor de 3 a la predicción en caso de error
        predictions_5.append(3)
    x += 1
    print(f"Texto {x}: {output_5}")

print(predictions_5)
# Out:
# Texto 1: [{'label': 'LABEL_2', 'score': 0.6311589479446411}]
# Texto 2: [{'label': 'LABEL_2', 'score': 0.7894551753997803}]
# Texto 3: [{'label': 'LABEL_0', 'score': 0.5005853772163391}]
# Texto 4: [{'label': 'LABEL_2', 'score': 0.4797581732273102}]
# Texto 5: [{'label': 'LABEL_1', 'score': 0.54304438829422}]
# Texto 6: [{'label': 'LABEL_1', 'score': 0.7196619510650635}]
# Texto 7: [{'label': 'LABEL_1', 'score': 0.5181955695152283}]
# Texto 8: [{'label': 'LABEL_0', 'score': 0.593110978603363}]
# Texto 9: [{'label': 'LABEL_1', 'score': 0.5358076095581055}]
# Texto 10: [{'label': 'LABEL_0', 'score': 0.5516340136528015}]
# Texto 11: [{'label': 'LABEL_2', 'score': 0.980198085308075}]
# Texto 12: [{'label': 'LABEL_2', 'score': 0.9586889743804932}]
# Texto 13: [{'label': 'LABEL_1', 'score': 0.5506689548492432}]
# Texto 14: [{'label': 'LABEL_1', 'score': 0.5819634199142456}]
# Texto 15: [{'label': 'LABEL_2', 'score': 0.5148200988769531}]
# Texto 16: [{'label': 'LABEL_1', 'score': 0.49596545100212097}]
# Texto 17: [{'label': 'LABEL_1', 'score': 0.9006527066230774}]
# Texto 18: [{'label': 'LABEL_1', 'score': 0.5797280669212341}]
# Texto 19: [{'label': 'LABEL_1', 'score': 0.5237250328063965}]
# Texto 20: [{'label': 'LABEL_1', 'score': 0.572126567363739}]
# Texto 21: [{'label': 'LABEL_1', 'score': 0.5932979583740234}]
# Texto 22: [{'label': 'LABEL_1', 'score': 0.5831813812255859}]
# Texto 23: [{'label': 'LABEL_2', 'score': 0.9249731302261353}]
# Texto 24: [{'label': 'LABEL_1', 'score': 0.5901942253112793}]
# Texto 25: [{'label': 'LABEL_2', 'score': 0.6625880002975464}]
# Texto 26: [{'label': 'LABEL_2', 'score': 0.7793124318122864}]
# Texto 27: [{'label': 'LABEL_2', 'score': 0.6855756044387817}]
# Texto 28: [{'label': 'LABEL_1', 'score': 0.5160343647003174}]
# Texto 29: [{'label': 'LABEL_2', 'score': 0.8019548654556274}]
# Texto 30: [{'label': 'LABEL_0', 'score': 0.586034893989563}]
# Texto 31: [{'label': 'LABEL_1', 'score': 0.570952296257019}]
# Texto 32: [{'label': 'LABEL_1', 'score': 0.5144270658493042}]
# Texto 33: [{'label': 'LABEL_1', 'score': 0.5571669340133667}]
# Texto 34: [{'label': 'LABEL_0', 'score': 0.5532858371734619}]
# Texto 35: [{'label': 'LABEL_1', 'score': 0.7015981674194336}]
# Texto 36: [{'label': 'LABEL_1', 'score': 0.4631587862968445}]
# Texto 37: [{'label': 'LABEL_1', 'score': 0.5647360682487488}]
# Texto 38: [{'label': 'LABEL_0', 'score': 0.5667896270751953}]
# Texto 39: [{'label': 'LABEL_1', 'score': 0.5082619190216064}]
# Texto 40: [{'label': 'LABEL_0', 'score': 0.5463026165962219}]
# Texto 41: [{'label': 'LABEL_2', 'score': 0.6360995173454285}]
# Texto 42: [{'label': 'LABEL_1', 'score': 0.6559736728668213}]
# Texto 43: [{'label': 'LABEL_0', 'score': 0.7429203987121582}]
# Texto 44: [{'label': 'LABEL_1', 'score': 0.5186301469802856}]
# Texto 45: [{'label': 'LABEL_2', 'score': 0.6597790718078613}]
# Texto 46: [{'label': 'LABEL_1', 'score': 0.5403014421463013}]
# Texto 47: [{'label': 'LABEL_0', 'score': 0.47845834493637085}]
# Texto 48: [{'label': 'LABEL_2', 'score': 0.5366083383560181}]
# Texto 49: [{'label': 'LABEL_2', 'score': 0.7781808376312256}]
# Texto 50: [{'label': 'LABEL_2', 'score': 0.5630539655685425}]
# Texto 51: [{'label': 'LABEL_2', 'score': 0.8384891748428345}]
# Texto 52: [{'label': 'LABEL_1', 'score': 0.4581086039543152}]
# Texto 53: [{'label': 'LABEL_2', 'score': 0.5658008456230164}]
# Texto 54: [{'label': 'LABEL_1', 'score': 0.5519799590110779}]
# Texto 55: [{'label': 'LABEL_2', 'score': 0.9437209367752075}]
# Texto 56: [{'label': 'LABEL_1', 'score': 0.5197932720184326}]
# Texto 57: [{'label': 'LABEL_1', 'score': 0.702597975730896}]
# Texto 58: [{'label': 'LABEL_1', 'score': 0.5940410494804382}]
# Texto 59: [{'label': 'LABEL_0', 'score': 0.5989863276481628}]
# Texto 60: [{'label': 'LABEL_2', 'score': 0.8312003016471863}]
# Texto 61: [{'label': 'LABEL_0', 'score': 0.7382799983024597}]
# Texto 62: [{'label': 'LABEL_1', 'score': 0.5689105987548828}]
# Texto 63: [{'label': 'LABEL_1', 'score': 0.5086937546730042}]
# Texto 64: [{'label': 'LABEL_1', 'score': 0.7131510972976685}]
# Texto 65: [{'label': 'LABEL_1', 'score': 0.6302052140235901}]
# Texto 66: [{'label': 'LABEL_1', 'score': 0.6253389716148376}]
# Texto 67: [{'label': 'LABEL_1', 'score': 0.6173266768455505}]
# Texto 68: [{'label': 'LABEL_2', 'score': 0.42394229769706726}]
# Texto 69: [{'label': 'LABEL_2', 'score': 0.5017727613449097}]
# Texto 70: [{'label': 'LABEL_0', 'score': 0.5074284672737122}]
# Texto 71: [{'label': 'LABEL_0', 'score': 0.6739979982376099}]
# Texto 72: [{'label': 'LABEL_0', 'score': 0.7211728692054749}]
# Texto 73: [{'label': 'LABEL_2', 'score': 0.7371236085891724}]
# Texto 74: [{'label': 'LABEL_1', 'score': 0.733759880065918}]
# Texto 75: [{'label': 'LABEL_1', 'score': 0.8267643451690674}]
# Texto 76: [{'label': 'LABEL_2', 'score': 0.8472090363502502}]
# Texto 77: [{'label': 'LABEL_2', 'score': 0.7594704031944275}]
# Texto 78: [{'label': 'LABEL_1', 'score': 0.6333104372024536}]
# Texto 79: [{'label': 'LABEL_2', 'score': 0.6994522213935852}]
# Texto 80: [{'label': 'LABEL_1', 'score': 0.5337167978286743}]
# Texto 81: [{'label': 'LABEL_2', 'score': 0.9136032462120056}]
# Texto 82: [{'label': 'LABEL_1', 'score': 0.692688524723053}]
# Texto 83: [{'label': 'LABEL_1', 'score': 0.8477834463119507}]
# Texto 84: [{'label': 'LABEL_1', 'score': 0.7604067325592041}]
# Texto 85: [{'label': 'LABEL_1', 'score': 0.5482667684555054}]
# Texto 86: [{'label': 'LABEL_1', 'score': 0.7416694760322571}]
# Texto 87: [{'label': 'LABEL_1', 'score': 0.5880070328712463}]
# Texto 88: [{'label': 'LABEL_1', 'score': 0.8682385087013245}]
# Texto 89: [{'label': 'LABEL_1', 'score': 0.607796311378479}]
# Texto 90: [{'label': 'LABEL_0', 'score': 0.6201729774475098}]
# Texto 91: [{'label': 'LABEL_0', 'score': 0.6354845762252808}]
# Texto 92: [{'label': 'LABEL_1', 'score': 0.6932314038276672}]
# Texto 93: [{'label': 'LABEL_1', 'score': 0.45337405800819397}]
# Texto 94: [{'label': 'LABEL_0', 'score': 0.6871024370193481}]
# Texto 95: [{'label': 'LABEL_1', 'score': 0.4989050328731537}]
# Texto 96: [{'label': 'LABEL_1', 'score': 0.6757224202156067}]
# Texto 97: [{'label': 'LABEL_1', 'score': 0.5739797353744507}]
# Texto 98: [{'label': 'LABEL_0', 'score': 0.48059648275375366}]
# Texto 99: [{'label': 'LABEL_0', 'score': 0.4542263150215149}]
# Texto 100: [{'label': 'LABEL_1', 'score': 0.5693805813789368}]
# Texto 101: [{'label': 'LABEL_1', 'score': 0.4989089369773865}]
# Texto 102: [{'label': 'LABEL_2', 'score': 0.6573767066001892}]
# Texto 103: [{'label': 'LABEL_1', 'score': 0.49155014753341675}]
# Texto 104: [{'label': 'LABEL_1', 'score': 0.7355102300643921}]
# Texto 105: [{'label': 'LABEL_2', 'score': 0.8222963213920593}]
# Texto 106: [{'label': 'LABEL_1', 'score': 0.5438185334205627}]
# Texto 107: [{'label': 'LABEL_2', 'score': 0.6994608044624329}]
# Texto 108: [{'label': 'LABEL_2', 'score': 0.5588712096214294}]
# Texto 109: [{'label': 'LABEL_0', 'score': 0.5913649201393127}]
# Texto 110: [{'label': 'LABEL_1', 'score': 0.7614473700523376}]
# Texto 111: [{'label': 'LABEL_1', 'score': 0.5122592449188232}]
# Texto 112: [{'label': 'LABEL_1', 'score': 0.6633790731430054}]
# Texto 113: [{'label': 'LABEL_1', 'score': 0.5409076809883118}]
# Texto 114: [{'label': 'LABEL_2', 'score': 0.6153850555419922}]
# Texto 115: [{'label': 'LABEL_1', 'score': 0.5521077513694763}]
# Texto 116: [{'label': 'LABEL_1', 'score': 0.7103155255317688}]
# Texto 117: [{'label': 'LABEL_1', 'score': 0.6463213562965393}]
# Texto 118: [{'label': 'LABEL_1', 'score': 0.8788302540779114}]
# Texto 119: [{'label': 'LABEL_1', 'score': 0.5399384498596191}]
# Texto 120: [{'label': 'LABEL_1', 'score': 0.5545534491539001}]
# Texto 121: [{'label': 'LABEL_2', 'score': 0.5530656576156616}]
# Texto 122: [{'label': 'LABEL_1', 'score': 0.6990799307823181}]
# Texto 123: [{'label': 'LABEL_1', 'score': 0.6377460360527039}]
# Texto 124: [{'label': 'LABEL_2', 'score': 0.5944045782089233}]
# Texto 125: [{'label': 'LABEL_1', 'score': 0.7082121968269348}]
# Texto 126: [{'label': 'LABEL_1', 'score': 0.5692647099494934}]
# Texto 127: [{'label': 'LABEL_2', 'score': 0.7044748067855835}]
# Texto 128: [{'label': 'LABEL_1', 'score': 0.8477222919464111}]
# Texto 129: [{'label': 'LABEL_1', 'score': 0.793953001499176}]
# Texto 130: [{'label': 'LABEL_0', 'score': 0.4692128598690033}]
# Texto 131: [{'label': 'LABEL_1', 'score': 0.5219506025314331}]
# Texto 132: [{'label': 'LABEL_1', 'score': 0.5474562048912048}]
# Texto 133: [{'label': 'LABEL_1', 'score': 0.5674217939376831}]
# Texto 134: [{'label': 'LABEL_0', 'score': 0.5537958741188049}]
# Texto 135: [{'label': 'LABEL_0', 'score': 0.6738215684890747}]
# Texto 136: [{'label': 'LABEL_1', 'score': 0.4707355797290802}]
# Texto 137: [{'label': 'LABEL_1', 'score': 0.5773665308952332}]
# Texto 138: [{'label': 'LABEL_0', 'score': 0.4973575174808502}]
# Texto 139: [{'label': 'LABEL_1', 'score': 0.6176493763923645}]
# Texto 140: [{'label': 'LABEL_0', 'score': 0.6015213131904602}]
# Texto 141: [{'label': 'LABEL_0', 'score': 0.4745677709579468}]
# Texto 142: [{'label': 'LABEL_1', 'score': 0.5295776724815369}]
# Texto 143: [{'label': 'LABEL_0', 'score': 0.5220499038696289}]
# Texto 144: [{'label': 'LABEL_2', 'score': 0.7509336471557617}]
# Texto 145: [{'label': 'LABEL_1', 'score': 0.5756813883781433}]
# Texto 146: [{'label': 'LABEL_0', 'score': 0.48659852147102356}]
# Texto 147: [{'label': 'LABEL_0', 'score': 0.5168473124504089}]
# Texto 148: [{'label': 'LABEL_0', 'score': 0.6200450658798218}]
# Texto 149: [{'label': 'LABEL_0', 'score': 0.5949274301528931}]
# Texto 150: [{'label': 'LABEL_1', 'score': 0.6762487292289734}]
# Texto 151: [{'label': 'LABEL_0', 'score': 0.6363872289657593}]
# Texto 152: [{'label': 'LABEL_0', 'score': 0.5886054039001465}]
# Texto 153: [{'label': 'LABEL_1', 'score': 0.5581188797950745}]
# Texto 154: [{'label': 'LABEL_0', 'score': 0.6403998732566833}]
# Texto 155: [{'label': 'LABEL_1', 'score': 0.5576666593551636}]
# Texto 156: [{'label': 'LABEL_0', 'score': 0.6007599830627441}]
# Texto 157: [{'label': 'LABEL_0', 'score': 0.668300986289978}]
# Texto 158: [{'label': 'LABEL_1', 'score': 0.48799628019332886}]
# Texto 159: [{'label': 'LABEL_0', 'score': 0.49073320627212524}]
# Texto 160: [{'label': 'LABEL_1', 'score': 0.6352075934410095}]
# Texto 161: [{'label': 'LABEL_0', 'score': 0.5133642554283142}]
# Texto 162: [{'label': 'LABEL_1', 'score': 0.5319597125053406}]
# Texto 163: [{'label': 'LABEL_1', 'score': 0.49592533707618713}]
# Texto 164: [{'label': 'LABEL_0', 'score': 0.4945250153541565}]
# Texto 165: [{'label': 'LABEL_0', 'score': 0.6585321426391602}]
# Texto 166: [{'label': 'LABEL_1', 'score': 0.7357544302940369}]
# Texto 167: [{'label': 'LABEL_0', 'score': 0.4723289906978607}]
# Texto 168: [{'label': 'LABEL_1', 'score': 0.48270323872566223}]
# Texto 169: [{'label': 'LABEL_0', 'score': 0.6826716661453247}]
# Texto 170: [{'label': 'LABEL_0', 'score': 0.4485820531845093}]
# Texto 171: [{'label': 'LABEL_0', 'score': 0.4846395254135132}]
# Texto 172: [{'label': 'LABEL_0', 'score': 0.5297196507453918}]
# Texto 173: [{'label': 'LABEL_1', 'score': 0.49684619903564453}]
# Texto 174: [{'label': 'LABEL_1', 'score': 0.5900489687919617}]
# Texto 175: [{'label': 'LABEL_0', 'score': 0.5710762143135071}]
# Texto 176: [{'label': 'LABEL_1', 'score': 0.4878288209438324}]
# Texto 177: [{'label': 'LABEL_0', 'score': 0.7703015804290771}]
# Texto 178: [{'label': 'LABEL_0', 'score': 0.6782540678977966}]
# Texto 179: [{'label': 'LABEL_1', 'score': 0.414754718542099}]
# Texto 180: [{'label': 'LABEL_1', 'score': 0.639412522315979}]
# Texto 181: [{'label': 'LABEL_1', 'score': 0.48648592829704285}]
# Texto 182: [{'label': 'LABEL_1', 'score': 0.4928362965583801}]
# Texto 183: [{'label': 'LABEL_1', 'score': 0.4734284281730652}]
# Texto 184: [{'label': 'LABEL_1', 'score': 0.5952741503715515}]
# Texto 185: [{'label': 'LABEL_0', 'score': 0.72170090675354}]
# Texto 186: [{'label': 'LABEL_0', 'score': 0.5667929649353027}]
# Texto 187: [{'label': 'LABEL_1', 'score': 0.828047513961792}]
# Texto 188: [{'label': 'LABEL_0', 'score': 0.5614240169525146}]
# Texto 189: [{'label': 'LABEL_1', 'score': 0.5393890142440796}]
# Texto 190: [{'label': 'LABEL_1', 'score': 0.5073711276054382}]
# Texto 191: [{'label': 'LABEL_1', 'score': 0.46410444378852844}]
# Texto 192: [{'label': 'LABEL_0', 'score': 0.7391272783279419}]
# Texto 193: [{'label': 'LABEL_1', 'score': 0.5760867595672607}]
# Texto 194: [{'label': 'LABEL_1', 'score': 0.510044515132904}]
# Texto 195: [{'label': 'LABEL_0', 'score': 0.7869842052459717}]
# Texto 196: [{'label': 'LABEL_0', 'score': 0.569819450378418}]
# Texto 197: [{'label': 'LABEL_0', 'score': 0.5786576867103577}]
# Texto 198: [{'label': 'LABEL_1', 'score': 0.560273289680481}]
# Texto 199: [{'label': 'LABEL_1', 'score': 0.5379346013069153}]
# Texto 200: [{'label': 'LABEL_1', 'score': 0.6340506076812744}]
# Texto 201: [{'label': 'LABEL_1', 'score': 0.4883791208267212}]
# Texto 202: [{'label': 'LABEL_1', 'score': 0.44299471378326416}]
# Texto 203: [{'label': 'LABEL_1', 'score': 0.6881766319274902}]
# Texto 204: [{'label': 'LABEL_2', 'score': 0.8352862000465393}]
# Texto 205: [{'label': 'LABEL_1', 'score': 0.4364374577999115}]
# Texto 206: [{'label': 'LABEL_0', 'score': 0.619853138923645}]
# Texto 207: [{'label': 'LABEL_1', 'score': 0.5341363549232483}]
# Texto 208: [{'label': 'LABEL_1', 'score': 0.755198061466217}]
# Texto 209: [{'label': 'LABEL_1', 'score': 0.479194700717926}]
# Texto 210: [{'label': 'LABEL_1', 'score': 0.4698362648487091}]
# Texto 211: [{'label': 'LABEL_2', 'score': 0.5167133212089539}]
# Texto 212: [{'label': 'LABEL_0', 'score': 0.7538904547691345}]
# Texto 213: [{'label': 'LABEL_1', 'score': 0.5107805132865906}]
# Texto 214: [{'label': 'LABEL_0', 'score': 0.5286350846290588}]
# Texto 215: [{'label': 'LABEL_0', 'score': 0.6404466032981873}]
# Texto 216: [{'label': 'LABEL_1', 'score': 0.625531792640686}]
# Texto 217: [{'label': 'LABEL_2', 'score': 0.6860188841819763}]
# Texto 218: [{'label': 'LABEL_0', 'score': 0.5170137286186218}]
# Texto 219: [{'label': 'LABEL_0', 'score': 0.4548942744731903}]
# Texto 220: [{'label': 'LABEL_2', 'score': 0.7905747294425964}]
# Texto 221: [{'label': 'LABEL_0', 'score': 0.5390194058418274}]
# Texto 222: [{'label': 'LABEL_1', 'score': 0.7451992630958557}]
# Texto 223: [{'label': 'LABEL_2', 'score': 0.5276735424995422}]
# Texto 224: [{'label': 'LABEL_1', 'score': 0.4486519992351532}]
# Texto 225: [{'label': 'LABEL_1', 'score': 0.4799198806285858}]
# Texto 226: [{'label': 'LABEL_0', 'score': 0.6193485856056213}]
# Texto 227: [{'label': 'LABEL_0', 'score': 0.4615847170352936}]
# Texto 228: [{'label': 'LABEL_0', 'score': 0.7020633816719055}]
# Texto 229: [{'label': 'LABEL_1', 'score': 0.47695261240005493}]
# Texto 230: [{'label': 'LABEL_0', 'score': 0.6026123762130737}]
# Texto 231: [{'label': 'LABEL_0', 'score': 0.7389130592346191}]
# Texto 232: [{'label': 'LABEL_1', 'score': 0.5507448315620422}]
# Texto 233: [{'label': 'LABEL_0', 'score': 0.5425970554351807}]
# Texto 234: [{'label': 'LABEL_1', 'score': 0.6554604768753052}]
# Texto 235: [{'label': 'LABEL_0', 'score': 0.548536479473114}]
# Texto 236: [{'label': 'LABEL_0', 'score': 0.6234180927276611}]
# Texto 237: [{'label': 'LABEL_1', 'score': 0.49866166710853577}]
# Texto 238: [{'label': 'LABEL_0', 'score': 0.8193277716636658}]
# Texto 239: [{'label': 'LABEL_1', 'score': 0.6236633062362671}]
# Texto 240: [{'label': 'LABEL_1', 'score': 0.4639318585395813}]
# Texto 241: [{'label': 'LABEL_1', 'score': 0.48936039209365845}]
# Texto 242: [{'label': 'LABEL_1', 'score': 0.6279010772705078}]
# Texto 243: [{'label': 'LABEL_1', 'score': 0.7928647994995117}]
# Texto 244: [{'label': 'LABEL_1', 'score': 0.5360995531082153}]
# Texto 245: [{'label': 'LABEL_1', 'score': 0.5747826099395752}]
# Texto 246: [{'label': 'LABEL_1', 'score': 0.5566959977149963}]
# Texto 247: [{'label': 'LABEL_1', 'score': 0.547349214553833}]
# Texto 248: [{'label': 'LABEL_0', 'score': 0.5030666589736938}]
# Texto 249: [{'label': 'LABEL_0', 'score': 0.8775184750556946}]
# Texto 250: [{'label': 'LABEL_2', 'score': 0.6879196763038635}]
# Texto 251: [{'label': 'LABEL_0', 'score': 0.9537526965141296}]
# Texto 252: [{'label': 'LABEL_0', 'score': 0.7623945474624634}]
# Texto 253: [{'label': 'LABEL_1', 'score': 0.4963090121746063}]
# Texto 254: [{'label': 'LABEL_1', 'score': 0.47285565733909607}]
# Texto 255: [{'label': 'LABEL_0', 'score': 0.7336131930351257}]
# Texto 256: [{'label': 'LABEL_0', 'score': 0.6431179642677307}]
# Texto 257: [{'label': 'LABEL_2', 'score': 0.5298318862915039}]
# Texto 258: [{'label': 'LABEL_2', 'score': 0.467946320772171}]
# Texto 259: [{'label': 'LABEL_0', 'score': 0.6882776021957397}]
# Texto 260: [{'label': 'LABEL_1', 'score': 0.6747644543647766}]
# Texto 261: [{'label': 'LABEL_0', 'score': 0.525402307510376}]
# Texto 262: [{'label': 'LABEL_0', 'score': 0.49520382285118103}]
# Texto 263: [{'label': 'LABEL_0', 'score': 0.6871550679206848}]
# Texto 264: [{'label': 'LABEL_0', 'score': 0.8262995481491089}]
# Texto 265: [{'label': 'LABEL_1', 'score': 0.5736462473869324}]
# Texto 266: [{'label': 'LABEL_1', 'score': 0.567367672920227}]
# Texto 267: [{'label': 'LABEL_1', 'score': 0.6346706748008728}]
# Texto 268: [{'label': 'LABEL_1', 'score': 0.544067919254303}]
# Texto 269: [{'label': 'LABEL_0', 'score': 0.6812341809272766}]
# Texto 270: [{'label': 'LABEL_0', 'score': 0.5375678539276123}]
# Texto 271: [{'label': 'LABEL_1', 'score': 0.5325018167495728}]
# Texto 272: [{'label': 'LABEL_0', 'score': 0.7350384593009949}]
# Texto 273: [{'label': 'LABEL_1', 'score': 0.656955897808075}]
# Texto 274: [{'label': 'LABEL_0', 'score': 0.4801124930381775}]
# Texto 275: [{'label': 'LABEL_0', 'score': 0.5604430437088013}]
# Texto 276: [{'label': 'LABEL_0', 'score': 0.45917919278144836}]
# Texto 277: [{'label': 'LABEL_0', 'score': 0.7076876759529114}]
# Texto 278: [{'label': 'LABEL_0', 'score': 0.7342101335525513}]
# Texto 279: [{'label': 'LABEL_1', 'score': 0.6004493236541748}]
# Texto 280: [{'label': 'LABEL_2', 'score': 0.530087411403656}]
# Texto 281: [{'label': 'LABEL_1', 'score': 0.5617918968200684}]
# Texto 282: [{'label': 'LABEL_0', 'score': 0.5677329301834106}]
# Texto 283: [{'label': 'LABEL_0', 'score': 0.6470928192138672}]
# Texto 284: [{'label': 'LABEL_1', 'score': 0.58909010887146}]
# Texto 285: [{'label': 'LABEL_1', 'score': 0.4919961392879486}]
# Texto 286: [{'label': 'LABEL_0', 'score': 0.5439462661743164}]
# Texto 287: [{'label': 'LABEL_0', 'score': 0.6059635877609253}]
# Texto 288: [{'label': 'LABEL_0', 'score': 0.7672790288925171}]
# Texto 289: [{'label': 'LABEL_2', 'score': 0.6241176724433899}]
# Texto 290: [{'label': 'LABEL_1', 'score': 0.47975486516952515}]
# Texto 291: [{'label': 'LABEL_1', 'score': 0.5166236758232117}]
# Texto 292: [{'label': 'LABEL_0', 'score': 0.5760059952735901}]
# Texto 293: [{'label': 'LABEL_0', 'score': 0.6435980200767517}]
# Texto 294: [{'label': 'LABEL_0', 'score': 0.620077908039093}]
# Texto 295: [{'label': 'LABEL_1', 'score': 0.5492132306098938}]
# Texto 296: [{'label': 'LABEL_0', 'score': 0.48277080059051514}]
# Texto 297: [{'label': 'LABEL_0', 'score': 0.6238500475883484}]
# Texto 298: [{'label': 'LABEL_1', 'score': 0.4984143078327179}]
# Texto 299: [{'label': 'LABEL_1', 'score': 0.48384469747543335}]
# Texto 300: [{'label': 'LABEL_1', 'score': 0.5994464755058289}]
# Texto 301: [{'label': 'LABEL_0', 'score': 0.5458539128303528}]
# Texto 302: [{'label': 'LABEL_0', 'score': 0.517295777797699}]
# Texto 303: [{'label': 'LABEL_1', 'score': 0.5210418105125427}]
# Texto 304: [{'label': 'LABEL_0', 'score': 0.758872926235199}]
# Texto 305: [{'label': 'LABEL_2', 'score': 0.5836257338523865}]
# Texto 306: [{'label': 'LABEL_1', 'score': 0.693119466304779}]
# Texto 307: [{'label': 'LABEL_0', 'score': 0.572332501411438}]
# Texto 308: [{'label': 'LABEL_1', 'score': 0.48847848176956177}]
# Texto 309: [{'label': 'LABEL_0', 'score': 0.4871757924556732}]
# Texto 310: [{'label': 'LABEL_1', 'score': 0.563636302947998}]
# Texto 311: [{'label': 'LABEL_0', 'score': 0.4828467071056366}]
# Texto 312: [{'label': 'LABEL_1', 'score': 0.895085871219635}]
# Texto 313: [{'label': 'LABEL_0', 'score': 0.5733835697174072}]
# Texto 314: [{'label': 'LABEL_1', 'score': 0.6723052859306335}]
# Texto 315: [{'label': 'LABEL_1', 'score': 0.5575990080833435}]
# Texto 316: [{'label': 'LABEL_1', 'score': 0.579062819480896}]
# Texto 317: [{'label': 'LABEL_1', 'score': 0.5212339162826538}]
# Texto 318: [{'label': 'LABEL_1', 'score': 0.4715966284275055}]
# Texto 319: [{'label': 'LABEL_1', 'score': 0.6885908842086792}]
# Texto 320: [{'label': 'LABEL_1', 'score': 0.5184674859046936}]
# Texto 321: [{'label': 'LABEL_1', 'score': 0.4643805921077728}]
# Texto 322: [{'label': 'LABEL_0', 'score': 0.5314330458641052}]
# Texto 323: [{'label': 'LABEL_2', 'score': 0.888695478439331}]
# Texto 324: [{'label': 'LABEL_1', 'score': 0.5338238477706909}]
# Texto 325: [{'label': 'LABEL_2', 'score': 0.6346363425254822}]
# Texto 326: [{'label': 'LABEL_0', 'score': 0.8512004017829895}]
# Texto 327: [{'label': 'LABEL_1', 'score': 0.46109291911125183}]
# Texto 328: [{'label': 'LABEL_0', 'score': 0.7159104943275452}]
# Texto 329: [{'label': 'LABEL_1', 'score': 0.4746451675891876}]
# Texto 330: [{'label': 'LABEL_0', 'score': 0.48093006014823914}]
# Texto 331: [{'label': 'LABEL_1', 'score': 0.6653542518615723}]
# Texto 332: [{'label': 'LABEL_0', 'score': 0.7546841502189636}]
# Texto 333: [{'label': 'LABEL_0', 'score': 0.5795324444770813}]
# Texto 334: [{'label': 'LABEL_0', 'score': 0.5380073189735413}]
# Texto 335: [{'label': 'LABEL_1', 'score': 0.6350136399269104}]
# Texto 336: [{'label': 'LABEL_1', 'score': 0.5409680008888245}]
# Texto 337: [{'label': 'LABEL_1', 'score': 0.502558171749115}]
# Texto 338: [{'label': 'LABEL_1', 'score': 0.5360962152481079}]
# Texto 339: [{'label': 'LABEL_1', 'score': 0.7901482582092285}]
# Texto 340: [{'label': 'LABEL_2', 'score': 0.4613308608531952}]
# Texto 341: [{'label': 'LABEL_2', 'score': 0.9521071910858154}]
# Texto 342: [{'label': 'LABEL_1', 'score': 0.4895540177822113}]
# Texto 343: [{'label': 'LABEL_1', 'score': 0.5746371746063232}]
# Texto 344: [{'label': 'LABEL_1', 'score': 0.5014885663986206}]
# Texto 345: [{'label': 'LABEL_0', 'score': 0.5452103018760681}]
# Texto 346: [{'label': 'LABEL_2', 'score': 0.8395095467567444}]
# Texto 347: [{'label': 'LABEL_1', 'score': 0.6328397989273071}]
# Texto 348: [{'label': 'LABEL_0', 'score': 0.5336307287216187}]
# Texto 349: [{'label': 'LABEL_1', 'score': 0.5265193581581116}]
# Texto 350: [{'label': 'LABEL_1', 'score': 0.46171316504478455}]
# Texto 351: [{'label': 'LABEL_1', 'score': 0.5284950733184814}]
# Texto 352: [{'label': 'LABEL_0', 'score': 0.6010213494300842}]
# Texto 353: [{'label': 'LABEL_1', 'score': 0.48726317286491394}]
# Texto 354: [{'label': 'LABEL_1', 'score': 0.6339991092681885}]
# Texto 355: [{'label': 'LABEL_2', 'score': 0.8571797609329224}]
# Texto 356: [{'label': 'LABEL_1', 'score': 0.6458357572555542}]
# Texto 357: [{'label': 'LABEL_1', 'score': 0.4712255895137787}]
# Texto 358: [{'label': 'LABEL_0', 'score': 0.7565531134605408}]
# Texto 359: [{'label': 'LABEL_0', 'score': 0.5111077427864075}]
# Texto 360: [{'label': 'LABEL_2', 'score': 0.8065699934959412}]
# Texto 361: [{'label': 'LABEL_2', 'score': 0.8039506077766418}]
# Texto 362: [{'label': 'LABEL_1', 'score': 0.46672332286834717}]
# Texto 363: [{'label': 'LABEL_1', 'score': 0.47319820523262024}]
# Texto 364: [{'label': 'LABEL_1', 'score': 0.4953184425830841}]
# Texto 365: [{'label': 'LABEL_1', 'score': 0.7098395228385925}]
# Texto 366: [{'label': 'LABEL_1', 'score': 0.6988340020179749}]
# Texto 367: [{'label': 'LABEL_0', 'score': 0.5988262891769409}]
# Texto 368: [{'label': 'LABEL_0', 'score': 0.6720862984657288}]
# Texto 369: [{'label': 'LABEL_1', 'score': 0.812766432762146}]
# Texto 370: [{'label': 'LABEL_1', 'score': 0.5762327313423157}]
# Texto 371: [{'label': 'LABEL_1', 'score': 0.6784730553627014}]
# Texto 372: [{'label': 'LABEL_1', 'score': 0.7542669177055359}]
# Texto 373: [{'label': 'LABEL_0', 'score': 0.5071403384208679}]
# Texto 374: [{'label': 'LABEL_1', 'score': 0.5328734517097473}]
# Texto 375: [{'label': 'LABEL_1', 'score': 0.5532532334327698}]
# Texto 376: [{'label': 'LABEL_0', 'score': 0.6882568597793579}]
# Texto 377: [{'label': 'LABEL_1', 'score': 0.5505169034004211}]
# Texto 378: [{'label': 'LABEL_1', 'score': 0.5948652625083923}]
# Texto 379: [{'label': 'LABEL_1', 'score': 0.5662529468536377}]
# Texto 380: [{'label': 'LABEL_1', 'score': 0.5550511479377747}]
# Texto 381: [{'label': 'LABEL_1', 'score': 0.8525049090385437}]
# Texto 382: [{'label': 'LABEL_1', 'score': 0.4984692335128784}]
# Texto 383: [{'label': 'LABEL_2', 'score': 0.5416157841682434}]
# Texto 384: [{'label': 'LABEL_1', 'score': 0.5620841383934021}]
# Texto 385: [{'label': 'LABEL_1', 'score': 0.5792022347450256}]
# Texto 386: [{'label': 'LABEL_2', 'score': 0.48448625206947327}]
# Texto 387: [{'label': 'LABEL_1', 'score': 0.6263773441314697}]
# Texto 388: [{'label': 'LABEL_1', 'score': 0.7316173911094666}]
# Texto 389: [{'label': 'LABEL_1', 'score': 0.8366209268569946}]
# Texto 390: [{'label': 'LABEL_1', 'score': 0.5533479452133179}]
# Texto 391: [{'label': 'LABEL_1', 'score': 0.8819943070411682}]
# Texto 392: [{'label': 'LABEL_0', 'score': 0.7281693816184998}]
# Texto 393: [{'label': 'LABEL_0', 'score': 0.900912880897522}]
# Texto 394: [{'label': 'LABEL_2', 'score': 0.774450957775116}]
# Texto 395: [{'label': 'LABEL_0', 'score': 0.4826594591140747}]
# Texto 396: [{'label': 'LABEL_1', 'score': 0.8802614212036133}]
# Texto 397: [{'label': 'LABEL_0', 'score': 0.6334112882614136}]
# Texto 398: [{'label': 'LABEL_1', 'score': 0.5527914762496948}]
# Texto 399: [{'label': 'LABEL_1', 'score': 0.5053080320358276}]
# Texto 400: [{'label': 'LABEL_1', 'score': 0.8671797513961792}]
# Texto 401: [{'label': 'LABEL_1', 'score': 0.6331105828285217}]
# Texto 402: [{'label': 'LABEL_1', 'score': 0.5497744679450989}]
# Texto 403: [{'label': 'LABEL_1', 'score': 0.8522828817367554}]
# Texto 404: [{'label': 'LABEL_2', 'score': 0.788517415523529}]
# Texto 405: [{'label': 'LABEL_1', 'score': 0.5504615902900696}]
# Texto 406: [{'label': 'LABEL_1', 'score': 0.6009301543235779}]
# Texto 407: [{'label': 'LABEL_0', 'score': 0.6231699585914612}]
# Texto 408: [{'label': 'LABEL_1', 'score': 0.46487823128700256}]
# Texto 409: [{'label': 'LABEL_0', 'score': 0.5943912267684937}]
# Texto 410: [{'label': 'LABEL_0', 'score': 0.515006422996521}]
# Texto 411: [{'label': 'LABEL_1', 'score': 0.5382944941520691}]
# Texto 412: [{'label': 'LABEL_0', 'score': 0.48626652359962463}]
# Texto 413: [{'label': 'LABEL_1', 'score': 0.6936149597167969}]
# Texto 414: [{'label': 'LABEL_1', 'score': 0.7001128792762756}]
# Texto 415: [{'label': 'LABEL_1', 'score': 0.4955995976924896}]
# Texto 416: [{'label': 'LABEL_0', 'score': 0.5086276531219482}]
# Texto 417: [{'label': 'LABEL_2', 'score': 0.5084279775619507}]
# Texto 418: [{'label': 'LABEL_1', 'score': 0.6388100385665894}]
# Texto 419: [{'label': 'LABEL_1', 'score': 0.7917402982711792}]
# Texto 420: [{'label': 'LABEL_0', 'score': 0.5441896915435791}]
# Texto 421: [{'label': 'LABEL_1', 'score': 0.8142154216766357}]
# Texto 422: [{'label': 'LABEL_1', 'score': 0.7616576552391052}]
# Texto 423: [{'label': 'LABEL_1', 'score': 0.4937632381916046}]
# Texto 424: [{'label': 'LABEL_1', 'score': 0.4740448594093323}]
# Texto 425: [{'label': 'LABEL_1', 'score': 0.6591776609420776}]
# Texto 426: [{'label': 'LABEL_1', 'score': 0.7082435488700867}]
# Texto 427: [{'label': 'LABEL_1', 'score': 0.8206591606140137}]
# Texto 428: [{'label': 'LABEL_1', 'score': 0.5278841853141785}]
# Texto 429: [{'label': 'LABEL_1', 'score': 0.5507186055183411}]
# Texto 430: [{'label': 'LABEL_1', 'score': 0.4050244987010956}]
# Texto 431: [{'label': 'LABEL_1', 'score': 0.6102346181869507}]
# Texto 432: [{'label': 'LABEL_1', 'score': 0.5461820363998413}]
# Texto 433: [{'label': 'LABEL_1', 'score': 0.509698212146759}]
# Texto 434: [{'label': 'LABEL_1', 'score': 0.4663434326648712}]
# Texto 435: [{'label': 'LABEL_1', 'score': 0.7381205558776855}]
# Texto 436: [{'label': 'LABEL_1', 'score': 0.6006036400794983}]
# Texto 437: [{'label': 'LABEL_1', 'score': 0.6126478314399719}]
# Texto 438: [{'label': 'LABEL_0', 'score': 0.6075185537338257}]
# Texto 439: [{'label': 'LABEL_1', 'score': 0.7888501286506653}]
# Texto 440: [{'label': 'LABEL_1', 'score': 0.5304340124130249}]
# Texto 441: [{'label': 'LABEL_2', 'score': 0.6366648077964783}]
# Texto 442: [{'label': 'LABEL_1', 'score': 0.6809472441673279}]
# Texto 443: [{'label': 'LABEL_2', 'score': 0.6457385420799255}]
# Texto 444: [{'label': 'LABEL_1', 'score': 0.46789923310279846}]
# Texto 445: [{'label': 'LABEL_2', 'score': 0.6408731341362}]
# Texto 446: [{'label': 'LABEL_1', 'score': 0.5611332058906555}]
# Texto 447: [{'label': 'LABEL_1', 'score': 0.7425739765167236}]
# Texto 448: [{'label': 'LABEL_0', 'score': 0.4769561290740967}]
# Texto 449: [{'label': 'LABEL_1', 'score': 0.8770306706428528}]
# Texto 450: [{'label': 'LABEL_2', 'score': 0.5549657940864563}]
# Texto 451: [{'label': 'LABEL_1', 'score': 0.69419926404953}]
# Texto 452: [{'label': 'LABEL_1', 'score': 0.8513080477714539}]
# Texto 453: [{'label': 'LABEL_1', 'score': 0.849676251411438}]
# Texto 454: [{'label': 'LABEL_1', 'score': 0.6455242037773132}]
# Texto 455: [{'label': 'LABEL_0', 'score': 0.521913468837738}]
# Texto 456: [{'label': 'LABEL_1', 'score': 0.6929485201835632}]
# Texto 457: [{'label': 'LABEL_1', 'score': 0.7233136296272278}]
# Texto 458: [{'label': 'LABEL_1', 'score': 0.6446654200553894}]
# Texto 459: [{'label': 'LABEL_0', 'score': 0.47970306873321533}]
# Texto 460: [{'label': 'LABEL_1', 'score': 0.6849649548530579}]
# Texto 461: [{'label': 'LABEL_1', 'score': 0.5570164918899536}]
# Texto 462: [{'label': 'LABEL_1', 'score': 0.6255959272384644}]
# Texto 463: [{'label': 'LABEL_1', 'score': 0.6241894364356995}]
# Texto 464: [{'label': 'LABEL_1', 'score': 0.7029802799224854}]
# Texto 465: [{'label': 'LABEL_0', 'score': 0.5237735509872437}]
# Texto 466: [{'label': 'LABEL_2', 'score': 0.6852089166641235}]
# Texto 467: [{'label': 'LABEL_1', 'score': 0.8748025894165039}]
# Texto 468: [{'label': 'LABEL_1', 'score': 0.8962337374687195}]
# Texto 469: [{'label': 'LABEL_1', 'score': 0.527898907661438}]
# Texto 470: [{'label': 'LABEL_0', 'score': 0.5954847931861877}]
# Texto 471: [{'label': 'LABEL_2', 'score': 0.8162215948104858}]
# Texto 472: [{'label': 'LABEL_1', 'score': 0.590916633605957}]
# Texto 473: [{'label': 'LABEL_1', 'score': 0.5374755263328552}]
# Texto 474: [{'label': 'LABEL_1', 'score': 0.7026270031929016}]
# Texto 475: [{'label': 'LABEL_0', 'score': 0.5155025124549866}]
# Texto 476: [{'label': 'LABEL_1', 'score': 0.6262450814247131}]
# Texto 477: [{'label': 'LABEL_0', 'score': 0.7115271687507629}]
# Texto 478: [{'label': 'LABEL_1', 'score': 0.545164167881012}]
# Texto 479: [{'label': 'LABEL_1', 'score': 0.8907107710838318}]
# Texto 480: [{'label': 'LABEL_0', 'score': 0.7387547492980957}]
# Texto 481: [{'label': 'LABEL_0', 'score': 0.8046644926071167}]
# Texto 482: [{'label': 'LABEL_0', 'score': 0.5969882011413574}]
# Texto 483: [{'label': 'LABEL_1', 'score': 0.8120088577270508}]
# Texto 484: [{'label': 'LABEL_1', 'score': 0.8081914186477661}]
# Texto 485: [{'label': 'LABEL_2', 'score': 0.8819953203201294}]
# Texto 486: [{'label': 'LABEL_2', 'score': 0.672643780708313}]
# Texto 487: [{'label': 'LABEL_1', 'score': 0.6200723648071289}]
# Texto 488: [{'label': 'LABEL_1', 'score': 0.49467232823371887}]
# Texto 489: [{'label': 'LABEL_2', 'score': 0.8348081111907959}]
# Texto 490: [{'label': 'LABEL_1', 'score': 0.6835959553718567}]
# Texto 491: [{'label': 'LABEL_1', 'score': 0.5877314805984497}]
# Texto 492: [{'label': 'LABEL_2', 'score': 0.6432384252548218}]
# Texto 493: [{'label': 'LABEL_0', 'score': 0.47022637724876404}]
# Texto 494: [{'label': 'LABEL_0', 'score': 0.45772022008895874}]
# Texto 495: [{'label': 'LABEL_2', 'score': 0.7524030804634094}]
# Texto 496: [{'label': 'LABEL_1', 'score': 0.5941759943962097}]
# Texto 497: [{'label': 'LABEL_1', 'score': 0.634386420249939}]
# Texto 498: [{'label': 'LABEL_1', 'score': 0.5851220488548279}]
# Texto 499: [{'label': 'LABEL_2', 'score': 0.5399795770645142}]
# Texto 500: [{'label': 'LABEL_1', 'score': 0.6655128002166748}]
# Texto 501: [{'label': 'LABEL_1', 'score': 0.4799001216888428}]
# Texto 502: [{'label': 'LABEL_1', 'score': 0.5500099658966064}]
# Texto 503: [{'label': 'LABEL_2', 'score': 0.5982001423835754}]
# Texto 504: [{'label': 'LABEL_1', 'score': 0.8605035543441772}]
# Texto 505: [{'label': 'LABEL_1', 'score': 0.5225816369056702}]
# Texto 506: [{'label': 'LABEL_1', 'score': 0.5015751719474792}]
# Texto 507: [{'label': 'LABEL_1', 'score': 0.5389732718467712}]
# Texto 508: [{'label': 'LABEL_1', 'score': 0.5909343361854553}]
# Texto 509: [{'label': 'LABEL_0', 'score': 0.8340977430343628}]
# Texto 510: [{'label': 'LABEL_0', 'score': 0.7580069303512573}]
# Texto 511: [{'label': 'LABEL_1', 'score': 0.6552802324295044}]
# Texto 512: [{'label': 'LABEL_1', 'score': 0.5205205678939819}]
# Texto 513: [{'label': 'LABEL_1', 'score': 0.5819162726402283}]
# Texto 514: [{'label': 'LABEL_1', 'score': 0.6097903847694397}]
# Texto 515: [{'label': 'LABEL_2', 'score': 0.8474310636520386}]
# Texto 516: [{'label': 'LABEL_2', 'score': 0.8472213745117188}]
# Texto 517: [{'label': 'LABEL_1', 'score': 0.5100829601287842}]
# Texto 518: [{'label': 'LABEL_0', 'score': 0.7801904678344727}]
# Texto 519: [{'label': 'LABEL_0', 'score': 0.4858758747577667}]
# Texto 520: [{'label': 'LABEL_0', 'score': 0.5690473914146423}]
# Texto 521: [{'label': 'LABEL_0', 'score': 0.4770296812057495}]
# Texto 522: [{'label': 'LABEL_0', 'score': 0.47689902782440186}]
# Texto 523: [{'label': 'LABEL_0', 'score': 0.6389881372451782}]
# Texto 524: [{'label': 'LABEL_0', 'score': 0.5330031514167786}]
# Texto 525: [{'label': 'LABEL_0', 'score': 0.5183652639389038}]
# Texto 526: [{'label': 'LABEL_0', 'score': 0.5269985795021057}]
# Texto 527: [{'label': 'LABEL_0', 'score': 0.7439145445823669}]
# Texto 528: [{'label': 'LABEL_0', 'score': 0.7205950617790222}]
# Texto 529: [{'label': 'LABEL_0', 'score': 0.5200284719467163}]
# Texto 530: [{'label': 'LABEL_0', 'score': 0.581991970539093}]
# Texto 531: [{'label': 'LABEL_1', 'score': 0.5499701499938965}]
# Texto 532: [{'label': 'LABEL_0', 'score': 0.5740268230438232}]
# Texto 533: [{'label': 'LABEL_0', 'score': 0.5241763591766357}]
# Texto 534: [{'label': 'LABEL_0', 'score': 0.7627530097961426}]
# Texto 535: [{'label': 'LABEL_1', 'score': 0.5553087592124939}]
# Texto 536: [{'label': 'LABEL_1', 'score': 0.48643288016319275}]
# Texto 537: [{'label': 'LABEL_1', 'score': 0.522636353969574}]
# Texto 538: [{'label': 'LABEL_0', 'score': 0.5008936524391174}]
# Texto 539: [{'label': 'LABEL_0', 'score': 0.8271567225456238}]
# Texto 540: [{'label': 'LABEL_0', 'score': 0.7730271220207214}]
# Texto 541: [{'label': 'LABEL_0', 'score': 0.6055265069007874}]
# Texto 542: [{'label': 'LABEL_0', 'score': 0.5406178832054138}]
# Texto 543: [{'label': 'LABEL_0', 'score': 0.8802319765090942}]
# Texto 544: [{'label': 'LABEL_0', 'score': 0.5565935969352722}]
# Texto 545: [{'label': 'LABEL_0', 'score': 0.5735175013542175}]
# Texto 546: [{'label': 'LABEL_0', 'score': 0.696649968624115}]
# Texto 547: [{'label': 'LABEL_1', 'score': 0.6766934394836426}]
# Texto 548: [{'label': 'LABEL_1', 'score': 0.6886177659034729}]
# Texto 549: [{'label': 'LABEL_0', 'score': 0.664269208908081}]
# Texto 550: [{'label': 'LABEL_0', 'score': 0.6374790072441101}]
# Texto 551: [{'label': 'LABEL_0', 'score': 0.672110915184021}]
# Texto 552: [{'label': 'LABEL_0', 'score': 0.5656617879867554}]
# Texto 553: [{'label': 'LABEL_0', 'score': 0.689291775226593}]
# Texto 554: [{'label': 'LABEL_1', 'score': 0.6442627906799316}]
# Texto 555: [{'label': 'LABEL_2', 'score': 0.47541460394859314}]
# Texto 556: [{'label': 'LABEL_1', 'score': 0.5012632608413696}]
# Texto 557: [{'label': 'LABEL_1', 'score': 0.5743706226348877}]
# Texto 558: [{'label': 'LABEL_1', 'score': 0.43974217772483826}]
# Texto 559: [{'label': 'LABEL_1', 'score': 0.5320570468902588}]
# Texto 560: [{'label': 'LABEL_0', 'score': 0.6382438540458679}]
# Texto 561: [{'label': 'LABEL_1', 'score': 0.5316298007965088}]
# Texto 562: [{'label': 'LABEL_0', 'score': 0.6369401812553406}]
# Texto 563: [{'label': 'LABEL_0', 'score': 0.5753500461578369}]
# Texto 564: [{'label': 'LABEL_1', 'score': 0.4413706660270691}]
# Texto 565: [{'label': 'LABEL_0', 'score': 0.6734764575958252}]
# Texto 566: [{'label': 'LABEL_0', 'score': 0.5455319881439209}]
# Texto 567: [{'label': 'LABEL_1', 'score': 0.5006129145622253}]
# Texto 568: [{'label': 'LABEL_2', 'score': 0.8043326735496521}]
# Texto 569: [{'label': 'LABEL_1', 'score': 0.6692622900009155}]
# Texto 570: [{'label': 'LABEL_1', 'score': 0.5854156017303467}]
# Texto 571: [{'label': 'LABEL_1', 'score': 0.4947437047958374}]
# Texto 572: [{'label': 'LABEL_0', 'score': 0.7479212880134583}]
# Texto 573: [{'label': 'LABEL_0', 'score': 0.5725769400596619}]
# Texto 574: [{'label': 'LABEL_0', 'score': 0.528577446937561}]
# Texto 575: [{'label': 'LABEL_0', 'score': 0.5182355642318726}]
# Texto 576: [{'label': 'LABEL_1', 'score': 0.5775365233421326}]
# Texto 577: [{'label': 'LABEL_0', 'score': 0.8365188837051392}]
# Texto 578: [{'label': 'LABEL_0', 'score': 0.6836062073707581}]
# Texto 579: [{'label': 'LABEL_0', 'score': 0.6578463912010193}]
# Texto 580: [{'label': 'LABEL_0', 'score': 0.6432573199272156}]
# Texto 581: [{'label': 'LABEL_1', 'score': 0.5434170365333557}]
# Texto 582: [{'label': 'LABEL_0', 'score': 0.591372549533844}]
# Texto 583: [{'label': 'LABEL_2', 'score': 0.5823296904563904}]
# Texto 584: [{'label': 'LABEL_0', 'score': 0.5057758092880249}]
# Texto 585: [{'label': 'LABEL_1', 'score': 0.5880208015441895}]
# Texto 586: [{'label': 'LABEL_1', 'score': 0.5435246825218201}]
# Texto 587: [{'label': 'LABEL_0', 'score': 0.8172135353088379}]
# Texto 588: [{'label': 'LABEL_0', 'score': 0.5893864035606384}]
# Texto 589: [{'label': 'LABEL_0', 'score': 0.5970076322555542}]
# Texto 590: [{'label': 'LABEL_0', 'score': 0.6685012578964233}]
# Texto 591: [{'label': 'LABEL_0', 'score': 0.7611274123191833}]
# Texto 592: [{'label': 'LABEL_1', 'score': 0.46813106536865234}]
# Texto 593: [{'label': 'LABEL_1', 'score': 0.5492280125617981}]
# Texto 594: [{'label': 'LABEL_0', 'score': 0.7378700375556946}]
# Texto 595: [{'label': 'LABEL_1', 'score': 0.5523543953895569}]
# Texto 596: [{'label': 'LABEL_1', 'score': 0.5545428395271301}]
# Texto 597: [{'label': 'LABEL_1', 'score': 0.5080748200416565}]
# Texto 598: [{'label': 'LABEL_1', 'score': 0.6065205931663513}]
# Texto 599: [{'label': 'LABEL_1', 'score': 0.5020648241043091}]
# Texto 600: [{'label': 'LABEL_1', 'score': 0.6779677271842957}]
# Texto 601: [{'label': 'LABEL_1', 'score': 0.43938958644866943}]
# Texto 602: [{'label': 'LABEL_0', 'score': 0.7012015581130981}]
# Texto 603: [{'label': 'LABEL_1', 'score': 0.5504679083824158}]
# Texto 604: [{'label': 'LABEL_1', 'score': 0.46949058771133423}]
# Texto 605: [{'label': 'LABEL_1', 'score': 0.5969700813293457}]
# Texto 606: [{'label': 'LABEL_1', 'score': 0.4666065573692322}]
# Texto 607: [{'label': 'LABEL_1', 'score': 0.5123144388198853}]
# Texto 608: [{'label': 'LABEL_1', 'score': 0.5482612252235413}]
# Texto 609: [{'label': 'LABEL_1', 'score': 0.4485282301902771}]
# Texto 610: [{'label': 'LABEL_1', 'score': 0.7863764762878418}]
# Texto 611: [{'label': 'LABEL_1', 'score': 0.7163249850273132}]
# Texto 612: [{'label': 'LABEL_2', 'score': 0.6313085556030273}]
# Texto 613: [{'label': 'LABEL_1', 'score': 0.5822416543960571}]
# Texto 614: [{'label': 'LABEL_2', 'score': 0.5993938446044922}]
# Texto 615: [{'label': 'LABEL_1', 'score': 0.5015273094177246}]
# Texto 616: [{'label': 'LABEL_1', 'score': 0.5722481608390808}]
# Texto 617: [{'label': 'LABEL_1', 'score': 0.6784969568252563}]
# Texto 618: [{'label': 'LABEL_1', 'score': 0.6121515035629272}]
# Texto 619: [{'label': 'LABEL_0', 'score': 0.4923536479473114}]
# Texto 620: [{'label': 'LABEL_0', 'score': 0.5205476880073547}]
# Texto 621: [{'label': 'LABEL_0', 'score': 0.7142527103424072}]
# Texto 622: [{'label': 'LABEL_1', 'score': 0.5420191287994385}]
# Texto 623: [{'label': 'LABEL_0', 'score': 0.5609734058380127}]
# Texto 624: [{'label': 'LABEL_2', 'score': 0.6353474855422974}]
# Texto 625: [{'label': 'LABEL_1', 'score': 0.47108960151672363}]
# Texto 626: [{'label': 'LABEL_0', 'score': 0.5493896007537842}]
# Texto 627: [{'label': 'LABEL_0', 'score': 0.5357653498649597}]
# Texto 628: [{'label': 'LABEL_0', 'score': 0.6412429213523865}]
# Texto 629: [{'label': 'LABEL_1', 'score': 0.6523110866546631}]
# Texto 630: [{'label': 'LABEL_1', 'score': 0.8593851327896118}]
# Texto 631: [{'label': 'LABEL_0', 'score': 0.5443469882011414}]
# Texto 632: [{'label': 'LABEL_2', 'score': 0.49007919430732727}]
# Texto 633: [{'label': 'LABEL_2', 'score': 0.6532350182533264}]
# Texto 634: [{'label': 'LABEL_2', 'score': 0.6260363459587097}]
# Texto 635: [{'label': 'LABEL_2', 'score': 0.8150846362113953}]
# Texto 636: [{'label': 'LABEL_0', 'score': 0.5019194483757019}]
# Texto 637: [{'label': 'LABEL_1', 'score': 0.6199479699134827}]
# Texto 638: [{'label': 'LABEL_1', 'score': 0.6041496992111206}]
# Texto 639: [{'label': 'LABEL_2', 'score': 0.501326322555542}]
# Texto 640: [{'label': 'LABEL_1', 'score': 0.6362292766571045}]
# Texto 641: [{'label': 'LABEL_2', 'score': 0.5231208801269531}]
# Texto 642: [{'label': 'LABEL_1', 'score': 0.694182813167572}]
# Texto 643: [{'label': 'LABEL_1', 'score': 0.8295448422431946}]
# Texto 644: [{'label': 'LABEL_1', 'score': 0.5798355937004089}]
# Texto 645: [{'label': 'LABEL_1', 'score': 0.4643901586532593}]
# Texto 646: [{'label': 'LABEL_1', 'score': 0.6273385286331177}]
# Texto 647: [{'label': 'LABEL_1', 'score': 0.6008043885231018}]
# Texto 648: [{'label': 'LABEL_1', 'score': 0.6367864012718201}]
# Texto 649: [{'label': 'LABEL_1', 'score': 0.6466073393821716}]
# Texto 650: [{'label': 'LABEL_0', 'score': 0.6064990758895874}]
# Texto 651: [{'label': 'LABEL_2', 'score': 0.5853195786476135}]
# Texto 652: [{'label': 'LABEL_1', 'score': 0.6706678867340088}]
# Texto 653: [{'label': 'LABEL_1', 'score': 0.5286799669265747}]
# Texto 654: [{'label': 'LABEL_1', 'score': 0.48868367075920105}]
# Texto 655: [{'label': 'LABEL_0', 'score': 0.5468354225158691}]
# Texto 656: [{'label': 'LABEL_0', 'score': 0.46571072936058044}]
# Texto 657: [{'label': 'LABEL_1', 'score': 0.503118097782135}]
# Texto 658: [{'label': 'LABEL_2', 'score': 0.8100736141204834}]
# Texto 659: [{'label': 'LABEL_0', 'score': 0.681993305683136}]
# Texto 660: [{'label': 'LABEL_0', 'score': 0.9608839154243469}]
# Texto 661: [{'label': 'LABEL_1', 'score': 0.5407864451408386}]
# Texto 662: [{'label': 'LABEL_0', 'score': 0.5292379856109619}]
# Texto 663: [{'label': 'LABEL_0', 'score': 0.5730152726173401}]
# Texto 664: [{'label': 'LABEL_1', 'score': 0.5657188296318054}]
# Texto 665: [{'label': 'LABEL_1', 'score': 0.5419945120811462}]
# Texto 666: [{'label': 'LABEL_0', 'score': 0.6178385615348816}]
# Texto 667: [{'label': 'LABEL_1', 'score': 0.6681927442550659}]
# Texto 668: [{'label': 'LABEL_0', 'score': 0.5870937705039978}]
# Texto 669: [{'label': 'LABEL_1', 'score': 0.7225722074508667}]
# [1, 1, 3, 1, 2, 2, 2, 3, 2, 3, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 1, 2, 1, 3, 2, 2, 2, 3, 2, 2, 2, 3, 2, 3, 1, 2, 3, 2, 1, 2, 3, 1, 1, 1, 1, 2, 1, 2, 1, 2, 2, 2, 3, 1, 3, 2, 2, 2, 2, 2, 2, 1, 1, 3, 3, 3, 1, 2, 2, 1, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 2, 2, 3, 2, 2, 2, 3, 3, 2, 2, 1, 2, 2, 1, 2, 1, 1, 3, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 3, 2, 2, 2, 3, 3, 2, 2, 3, 2, 3, 3, 2, 3, 1, 2, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 3, 3, 2, 3, 2, 3, 2, 2, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 2, 3, 2, 3, 3, 2, 2, 2, 2, 2, 2, 3, 3, 2, 3, 2, 2, 2, 3, 2, 2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 1, 2, 3, 2, 2, 2, 2, 1, 3, 2, 3, 3, 2, 1, 3, 3, 1, 3, 2, 1, 2, 2, 3, 3, 3, 2, 3, 3, 2, 3, 2, 3, 3, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 1, 3, 3, 2, 2, 3, 3, 1, 1, 3, 2, 3, 3, 3, 3, 2, 2, 2, 2, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 1, 2, 3, 3, 2, 2, 3, 3, 3, 1, 2, 2, 3, 3, 3, 2, 3, 3, 2, 2, 2, 3, 3, 2, 3, 1, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 2, 1, 3, 2, 3, 2, 3, 2, 3, 3, 3, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 3, 1, 2, 3, 2, 2, 2, 3, 2, 2, 1, 2, 2, 3, 3, 1, 1, 2, 2, 2, 2, 2, 3, 3, 2, 2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 3, 3, 1, 3, 2, 3, 2, 2, 2, 2, 2, 2, 1, 2, 2, 3, 2, 3, 3, 2, 3, 2, 2, 2, 3, 1, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 1, 2, 1, 2, 1, 2, 2, 3, 2, 1, 2, 2, 2, 2, 3, 2, 2, 2, 3, 2, 2, 2, 2, 2, 3, 1, 2, 2, 2, 3, 1, 2, 2, 2, 3, 2, 3, 2, 2, 3, 3, 3, 2, 2, 1, 1, 2, 2, 1, 2, 2, 1, 3, 3, 1, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 3, 3, 2, 2, 2, 2, 1, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 2, 1, 2, 2, 2, 2, 3, 2, 3, 3, 2, 3, 3, 2, 1, 2, 2, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 2, 3, 1, 3, 2, 2, 3, 3, 3, 3, 3, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 3, 3, 3, 2, 3, 1, 2, 3, 3, 3, 2, 2, 3, 1, 1, 1, 1, 3, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 2, 2, 2, 3, 3, 2, 1, 3, 3, 2, 3, 3, 2, 2, 3, 2, 3, 2]

# %%
# Obtener las etiquetas originales del conjunto de datos
y_true = data['label'].iloc[-669:]
print(y_true)

# Calcular el conteo de cada clase
class_counts = {label: predictions_5.count(label) for label in set(predictions_5)}

# Mostrar el conteo de cada clase
print("Conteo de cada clase:")
for label, count in class_counts.items():
    print(f"Clase {label}: {count} instancias")

# Crear el classification_report con las etiquetas originales del DataFrame 'data'
print("\nClassification Report:")
print(classification_report(y_true, predictions_5))
# Out:
# 1131    1
# 1132    1
# 1133    1
# 1134    1
# 1135    1
#        ..
# 1795    3
# 1796    3
# 1797    3
# 1798    3
# 1799    3
# Name: label, Length: 669, dtype: int64
# Conteo de cada clase:
# Clase 1: 89 instancias
# Clase 2: 362 instancias
# Clase 3: 218 instancias
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.48      0.27      0.35       160
#            2       0.61      0.56      0.58       395
#            3       0.27      0.51      0.35       114
#
#     accuracy                           0.48       669
#    macro avg       0.45      0.45      0.43       669
# weighted avg       0.52      0.48      0.49       669

# %%
# Crear un DataFrame con el texto y las predicciones
new_data_with_predictions = pd.DataFrame({'text': new_data_class_2['text'], 'label': predictions_5})

# Mostrar el nuevo DataFrame
print(new_data_with_predictions)

print(new_data)
# Out:
#                                                    text  label
# 1131  feel like text send back forth pretti flirtati...      1
# 1132  'm gon na pokemon thing get go outsid , bike ....      1
# 1133  someth work expos anxieti . even though 'm sta...      3
# 1134  absolut ! pleas encourag son . , make son exer...      1
# 1135  agre feel good thing . use go run track field ...      2
# ...                                                 ...    ...
# 1795  social anxieti : essenti . look around , felt ...      2
# 1796  eye contact . public . ca n't . hi , 'm 17 tho...      3
# 1797  look light , find . look dark , ever see.nnmi ...      2
# 1798  feel like sa ruin life . hi , hope okay post ....      3
# 1799  got social anxieti tri roller blade . 24 year ...      2
#
# [669 rows x 2 columns]
#                  keyword                                               text  \
# 0                    run  21/m . want experi young love , ve never relat...
# 1                 outsid  issu talk girl enjoy , sinc ignor pms most .. ...
# 2     run , swim , climb  need advic free social activ . ve come shell b...
# 3                   walk  spoke today .. week ago met girl colleg biolog...
# 4                 outsid  get social anxieti ? . hello , day girlfriend ...
# ...                  ...                                                ...
# 1126           basketbal  stiff . social anxieti make stiff ’ like muscl...
# 1127                 run  struggl set boundari friend alway come back bi...
# 1128                pool  think 'm make progress , realis far still go ....
# 1129                 run  help ? : ( . ’ know make friend . ’ 21 year ol...
# 1130       outsid , walk  random peopl take insecur ? . outsid break lad...
#
#       label  word_count  normalized_word_count
# 0         0          84                    0.0
# 1         0         204                    0.0
# 2         0         212                    0.0
# 3         0         234                    0.0
# 4         0         162                    0.0
# ...     ...         ...                    ...
# 1126      0          57                    0.0
# 1127      0         404                    0.0
# 1128      0         145                    0.0
# 1129      0         137                    0.0
# 1130      0          41                    0.0
#
# [1131 rows x 5 columns]

# %%
# Concatenar solo las columnas 'text' y 'label' de 'new_data' al DataFrame 'new_data_with_predictions'
pred_all_texts = pd.concat([new_data[['text', 'label']], new_data_with_predictions])

# Mostrar el nuevo DataFrame
print(pred_all_texts)
print(data)

# Evaluación del modelo en todos los datos
print("\nResultados en todos los datos:")
print(classification_report(data['label'], pred_all_texts['label']))
# Out:
#                                                    text  label
# 0     21/m . want experi young love , ve never relat...      0
# 1     issu talk girl enjoy , sinc ignor pms most .. ...      0
# 2     need advic free social activ . ve come shell b...      0
# 3     spoke today .. week ago met girl colleg biolog...      0
# 4     get social anxieti ? . hello , day girlfriend ...      0
# ...                                                 ...    ...
# 1795  social anxieti : essenti . look around , felt ...      2
# 1796  eye contact . public . ca n't . hi , 'm 17 tho...      3
# 1797  look light , find . look dark , ever see.nnmi ...      2
# 1798  feel like sa ruin life . hi , hope okay post ....      3
# 1799  got social anxieti tri roller blade . 24 year ...      2
#
# [1800 rows x 2 columns]
#            id                                keyword  \
# 0      3u2w5k                                    run
# 1      3xbury                                outside
# 2      3y743u                       run, swim, climb
# 3      43bvs7                                   walk
# 4      442ap2                                outside
# ...       ...                                    ...
# 1795   gqzye9                     pool, beach,  pool
# 1796   env299                     outside , outdoors
# 1797  e9bnr1s                                Jogging
# 1798   qrmhbe                  walk, swimming,  pool
# 1799   mxbsm8  roller blade, outside , roller blades
#
#                                                    text  label
# 0     21/m. I want to experience young love, but I'v...      0
# 1     Having issues talking to a girl whom I enjoyed...      0
# 2     Need some advice for free social activities. I...      0
# 3      I spoke to her today.. A few weeks ago I met ...      0
# 4     How to get over Social Anxiety?. Hello, The ot...      0
# ...                                                 ...    ...
# 1795   Social Anxiety: The Essentials. After looking...      3
# 1796   Eye contact. Being in public. I can't do it. ...      3
# 1797  If you look for the light, you will find it. I...      3
# 1798   I feel like my SA is ruining my life. Hi, I h...      3
# 1799  I got social anxiety trying to roller blade. S...      3
#
# [1800 rows x 4 columns]
#
# Resultados en todos los datos:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1131
#            1       0.48      0.27      0.35       160
#            2       0.61      0.56      0.58       395
#            3       0.27      0.51      0.35       114
#
#     accuracy                           0.81      1800
#    macro avg       0.59      0.58      0.57      1800
# weighted avg       0.82      0.81      0.81      1800
